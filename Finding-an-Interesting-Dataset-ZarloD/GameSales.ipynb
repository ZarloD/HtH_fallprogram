# %%
import pandas

pandas.options.display.max_columns = None
pandas.options.display.max_rows = None

csv_data = pandas.read_csv("GameSales.csv")
csv_data
# Out:
#                                                   Name  Sales  \
# 0                        PlayerUnknown's Battlegrounds   42.0
# 1                                            Minecraft   33.0
# 2                                           Diablo III   20.0
# 3                                          Garry's Mod   20.0
# 4                                             Terraria   17.2
# 5                                    World of Warcraft   14.0
# 6                                          Half-Life 2   12.0
# 7                             The Witcher 3: Wild Hunt   12.0
# 8                                            StarCraft   11.0
# 9                                             The Sims   11.0
# 10                                           Fall Guys   10.0
# 11                              RollerCoaster Tycoon 3   10.0
# 12                                           Half-Life    9.0
# 13                                                Rust    9.0
# ...
